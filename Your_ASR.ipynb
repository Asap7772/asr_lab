# %% [markdown]
# **Task:**
#
# 😊-------------------------------------------------------
#
# In this lab, you are going to make your speech recognizer. Specifically, given a pretrained wav2vec2 model, you should perform fine-tuning (FT) on your own speech data (English). You are required to collect **20 minutes** of your own voice that is recorded in either clean or noisy background. The content can be in any domains. Please just follow Gopala's voice format that will be given in the next few sections to deal with your voice data. Generally speaking, the duration of each utterance is suggested to be about **2s-5s**. But you can do any numbers. If it is 4s for each utterance, 20 minutes would correspond to about 300 utterances. Once you have 20 minutes data, you should perform 3 sets of experiments independently:
#
# 1. FT on the entire data (20minutes)
# 2. FT on 10 minutes data that is randomly sampled.
# 3. FT on 5 minutes data that is randomly sampled.
#
# For each experiment, please make sure to have train/dev/test split where the suggested ratio is 0.8 : 0.1 : 0.1. Please report WER for both dev and test set. That saying, you need **6 results in total**.
#
# Submission:
# Just **a doc or pdf file** that contains:
#
# (1) Colab links for all experiments. For example, if you do three experiments in three different colabs, just copy and paste all three links. If you just use one colab, then submit one.
#
# (2) Brief introduction of your collected corpus (where and how they were recorded, content domains, number of utterances, etc) and **your own data**! If you follow this code template and also use gdrive, please just copy and paste the gdrive link in the doc.
#
# (3) Brief analysis of the results.
#
# 😊-------------------------------------------------------

# %% [markdown]
# This code template is adapted from HugginFace [wav2vec2 code base](https://huggingface.co/docs/transformers/model_doc/wav2vec2).

# %% [markdown]
# Belowing is an example of performing fine-tuning on Gopala's voice with wav2vec2. You can follow this template and just replace the data with your own voice by following the same data format. So let's get started!

# %% [markdown]
# First, check GPU availablity. You are suggested to upgrade Colab Pro to have access to high-performance GPU. But it is not required.

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Tue Dec 20 00:32:26 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  A100-SXM4-40GB      Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    51W / 400W |      0MiB / 40536MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# Install both `datasets` and `transformers` from master. Also, we need the `librosa` package to load audio files and the `jiwer` to evaluate our fine-tuned model using the [word error rate (WER)](https://huggingface.co/metrics/wer) metric ${}^1$.

# %%
# %%capture
# !pip install datasets==1.18.3
# !pip install transformers==4.17.0
# !pip install jiwer

# %%
from datasets import load_dataset, load_metric

# %% [markdown]
# Below we have already prepared Gopala's voice that is saved in gdrive. Just download it unzip it.

# %%
#download gopala's voice
# !pip install -U --no-cache-dir gdown --pre
# !gdown https://drive.google.com/uc?id=1C8d1mFpwoISnrKYFuI1nEdd7xK3nwYJX
# !unzip data_gopala.zip
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gdown in /usr/local/lib/python3.8/dist-packages (4.4.0)
# Collecting gdown
#   Downloading gdown-4.6.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from gdown) (1.15.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from gdown) (4.64.1)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.8/dist-packages (from gdown) (2.23.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from gdown) (3.8.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.8/dist-packages (from gdown) (4.6.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->gdown) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->gdown) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->gdown) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->gdown) (1.24.3)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->gdown) (1.7.1)
# Installing collected packages: gdown
#   Attempting uninstall: gdown
#     Found existing installation: gdown 4.4.0
#     Uninstalling gdown-4.4.0:
#       Successfully uninstalled gdown-4.4.0
# Successfully installed gdown-4.6.0
# Downloading...
# From: https://drive.google.com/uc?id=1C8d1mFpwoISnrKYFuI1nEdd7xK3nwYJX
# To: /content/data_gopala.zip
# 100% 53.7M/53.7M [00:00<00:00, 83.5MB/s]
# Archive:  data_gopala.zip
#    creating: data_gopala/
#   inflating: __MACOSX/._data_gopala
#   inflating: data_gopala/arctic_a0026.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0026.wav
#   inflating: data_gopala/arctic_a0032.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0032.wav
#   inflating: data_gopala/arctic_a0581.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0581.wav
#   inflating: data_gopala/arctic_a0224.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0224.wav
#   inflating: data_gopala/arctic_a0542.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0542.wav
#   inflating: data_gopala/arctic_a0556.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0556.wav
#   inflating: data_gopala/arctic_a0230.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0230.wav
#   inflating: data_gopala/arctic_a0218.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0218.wav
#   inflating: data_gopala/arctic_a0393.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0393.wav
#   inflating: data_gopala/arctic_a0387.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0387.wav
#   inflating: data_gopala/arctic_a0350.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0350.wav
#   inflating: data_gopala/arctic_a0436.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0436.wav
#   inflating: data_gopala/arctic_a0422.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0422.wav
#   inflating: data_gopala/arctic_a0344.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0344.wav
#   inflating: data_gopala/arctic_a0378.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0378.wav
#   inflating: data_gopala/arctic_a0191.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0191.wav
#   inflating: data_gopala/arctic_a0185.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0185.wav
#   inflating: data_gopala/arctic_a0152.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0152.wav
#   inflating: data_gopala/arctic_a0146.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0146.wav
#   inflating: data_gopala/arctic_a0147.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0147.wav
#   inflating: data_gopala/arctic_a0153.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0153.wav
#   inflating: data_gopala/arctic_a0184.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0184.wav
#   inflating: data_gopala/arctic_a0190.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0190.wav
#   inflating: data_gopala/arctic_a0379.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0379.wav
#   inflating: data_gopala/arctic_a0423.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0423.wav
#   inflating: data_gopala/arctic_a0345.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0345.wav
#   inflating: data_gopala/arctic_a0351.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0351.wav
#   inflating: data_gopala/arctic_a0437.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0437.wav
#   inflating: data_gopala/arctic_a0386.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0386.wav
#   inflating: data_gopala/arctic_a0392.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0392.wav
#   inflating: data_gopala/arctic_a0219.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0219.wav
#   inflating: data_gopala/arctic_a0557.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0557.wav
#   inflating: data_gopala/arctic_a0231.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0231.wav
#   inflating: data_gopala/arctic_a0225.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0225.wav
#   inflating: data_gopala/arctic_a0543.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0543.wav
#   inflating: data_gopala/arctic_a0580.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0580.wav
#   inflating: data_gopala/arctic_a0033.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0033.wav
#   inflating: data_gopala/arctic_a0027.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0027.wav
#   inflating: data_gopala/arctic_a0031.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0031.wav
#   inflating: data_gopala/arctic_a0025.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0025.wav
#   inflating: data_gopala/arctic_a0019.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0019.wav
#   inflating: data_gopala/arctic_a0582.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0582.wav
#   inflating: data_gopala/arctic_a0233.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0233.wav
#   inflating: data_gopala/arctic_a0555.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0555.wav
#   inflating: data_gopala/arctic_a0541.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0541.wav
#   inflating: data_gopala/arctic_a0227.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0227.wav
#   inflating: data_gopala/arctic_a0569.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0569.wav
#   inflating: data_gopala/arctic_a0384.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0384.wav
#   inflating: data_gopala/arctic_a0390.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0390.wav
#   inflating: data_gopala/arctic_a0347.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0347.wav
#   inflating: data_gopala/arctic_a0421.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0421.wav
#   inflating: data_gopala/arctic_a0435.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0435.wav
#   inflating: data_gopala/arctic_a0353.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0353.wav
#   inflating: data_gopala/valid.csv
#   inflating: data_gopala/arctic_a0409.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0409.wav
#   inflating: data_gopala/arctic_a0186.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0186.wav
#   inflating: data_gopala/arctic_a0192.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0192.wav
#   inflating: data_gopala/arctic_a0145.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0145.wav
#   inflating: data_gopala/arctic_a0151.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0151.wav
#   inflating: data_gopala/arctic_a0179.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0179.wav
#   inflating: data_gopala/arctic_a0178.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0178.wav
#   inflating: data_gopala/arctic_a0150.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0150.wav
#   inflating: data_gopala/arctic_a0144.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0144.wav
#   inflating: data_gopala/arctic_a0193.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0193.wav
#   inflating: data_gopala/arctic_a0187.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0187.wav
#   inflating: data_gopala/arctic_a0408.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0408.wav
#   inflating: data_gopala/arctic_a0434.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0434.wav
#   inflating: data_gopala/arctic_a0352.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0352.wav
#   inflating: data_gopala/arctic_a0346.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0346.wav
#   inflating: data_gopala/arctic_a0420.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0420.wav
#   inflating: data_gopala/arctic_a0391.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0391.wav
#   inflating: data_gopala/arctic_a0385.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0385.wav
#   inflating: data_gopala/arctic_a0568.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0568.wav
#   inflating: data_gopala/arctic_a0540.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0540.wav
#   inflating: data_gopala/arctic_a0226.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0226.wav
#   inflating: data_gopala/arctic_a0232.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0232.wav
#   inflating: data_gopala/arctic_a0554.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0554.wav
#   inflating: data_gopala/arctic_a0583.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0583.wav
#   inflating: data_gopala/arctic_a0018.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0018.wav
#   inflating: data_gopala/arctic_a0024.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0024.wav
#   inflating: data_gopala/arctic_a0030.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0030.wav
#   inflating: data_gopala/arctic_a0008.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0008.wav
#   inflating: data_gopala/arctic_a0034.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0034.wav
#   inflating: data_gopala/arctic_a0020.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0020.wav
#   inflating: data_gopala/arctic_a0593.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0593.wav
#   inflating: data_gopala/arctic_a0587.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0587.wav
#   inflating: data_gopala/arctic_a0578.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0578.wav
#   inflating: data_gopala/arctic_a0550.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0550.wav
#   inflating: data_gopala/arctic_a0236.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0236.wav
#   inflating: data_gopala/arctic_a0222.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0222.wav
#   inflating: data_gopala/arctic_a0544.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0544.wav
#   inflating: data_gopala/arctic_a0381.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0381.wav
#   inflating: data_gopala/arctic_a0395.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0395.wav
#   inflating: data_gopala/arctic_a0418.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0418.wav
#   inflating: data_gopala/arctic_a0424.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0424.wav
#   inflating: data_gopala/arctic_a0342.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0342.wav
#   inflating: data_gopala/arctic_a0356.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0356.wav
#   inflating: data_gopala/arctic_a0430.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0430.wav
#   inflating: data_gopala/arctic_a0183.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0183.wav
#   inflating: data_gopala/arctic_a0197.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0197.wav
#   inflating: data_gopala/arctic_a0168.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0168.wav
#   inflating: data_gopala/arctic_a0140.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0140.wav
#   inflating: data_gopala/arctic_a0154.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0154.wav
#   inflating: data_gopala/arctic_a0155.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0155.wav
#   inflating: data_gopala/arctic_a0141.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0141.wav
#   inflating: data_gopala/arctic_a0169.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0169.wav
#   inflating: data_gopala/arctic_a0196.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0196.wav
#   inflating: data_gopala/arctic_a0182.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0182.wav
#   inflating: data_gopala/arctic_a0357.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0357.wav
#   inflating: data_gopala/arctic_a0431.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0431.wav
#   inflating: data_gopala/arctic_a0425.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0425.wav
#   inflating: data_gopala/arctic_a0343.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0343.wav
#   inflating: data_gopala/arctic_a0419.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0419.wav
#   inflating: data_gopala/arctic_a0394.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0394.wav
#   inflating: data_gopala/arctic_a0380.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0380.wav
#   inflating: data_gopala/arctic_a0223.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0223.wav
#   inflating: data_gopala/arctic_a0545.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0545.wav
#   inflating: data_gopala/arctic_a0551.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0551.wav
#   inflating: data_gopala/arctic_a0237.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0237.wav
#   inflating: data_gopala/arctic_a0579.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0579.wav
#   inflating: data_gopala/arctic_a0586.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0586.wav
#   inflating: data_gopala/arctic_a0592.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0592.wav
#   inflating: data_gopala/arctic_a0021.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0021.wav
#   inflating: data_gopala/arctic_a0035.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0035.wav
#   inflating: data_gopala/arctic_a0009.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0009.wav
#   inflating: data_gopala/arctic_a0023.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0023.wav
#   inflating: data_gopala/arctic_a0037.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0037.wav
#   inflating: data_gopala/arctic_a0584.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0584.wav
#   inflating: data_gopala/arctic_a0590.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0590.wav
#   inflating: data_gopala/arctic_a0209.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0209.wav
#   inflating: data_gopala/arctic_a0547.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0547.wav
#   inflating: data_gopala/arctic_a0221.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0221.wav
#   inflating: data_gopala/arctic_a0235.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0235.wav
#   inflating: data_gopala/arctic_a0553.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0553.wav
#   inflating: data_gopala/arctic_a0396.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0396.wav
#   inflating: data_gopala/arctic_a0382.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0382.wav
#   inflating: data_gopala/arctic_a0369.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0369.wav
#   inflating: data_gopala/arctic_a0433.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0433.wav
#   inflating: data_gopala/arctic_a0355.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0355.wav
#   inflating: data_gopala/arctic_a0341.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0341.wav
#   inflating: data_gopala/arctic_a0427.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0427.wav
#   inflating: data_gopala/arctic_a0194.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0194.wav
#   inflating: data_gopala/arctic_a0180.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0180.wav
#   inflating: data_gopala/arctic_a0157.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0157.wav
#   inflating: data_gopala/arctic_a0143.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0143.wav
#   inflating: data_gopala/arctic_a0142.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0142.wav
#   inflating: data_gopala/arctic_a0156.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0156.wav
#   inflating: data_gopala/arctic_a0181.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0181.wav
#   inflating: data_gopala/arctic_a0195.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0195.wav
#   inflating: data_gopala/arctic_a0340.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0340.wav
#   inflating: data_gopala/arctic_a0426.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0426.wav
#   inflating: data_gopala/arctic_a0432.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0432.wav
#   inflating: data_gopala/arctic_a0354.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0354.wav
#   inflating: data_gopala/arctic_a0368.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0368.wav
#   inflating: data_gopala/arctic_a0383.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0383.wav
#   inflating: data_gopala/arctic_a0397.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0397.wav
#   inflating: data_gopala/arctic_a0234.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0234.wav
#   inflating: data_gopala/arctic_a0552.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0552.wav
#   inflating: data_gopala/arctic_a0546.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0546.wav
#   inflating: data_gopala/arctic_a0220.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0220.wav
#   inflating: data_gopala/arctic_a0208.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0208.wav
#   inflating: data_gopala/arctic_a0591.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0591.wav
#   inflating: data_gopala/arctic_a0585.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0585.wav
#   inflating: data_gopala/arctic_a0036.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0036.wav
#   inflating: data_gopala/arctic_a0022.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0022.wav
#   inflating: data_gopala/arctic_a0086.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0086.wav
#   inflating: data_gopala/arctic_a0092.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0092.wav
#   inflating: data_gopala/arctic_a0045.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0045.wav
#   inflating: data_gopala/arctic_a0051.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0051.wav
#   inflating: data_gopala/arctic_a0079.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0079.wav
#   inflating: data_gopala/arctic_a0284.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0284.wav
#   inflating: data_gopala/arctic_a0290.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0290.wav
#   inflating: data_gopala/arctic_a0521.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0521.wav
#   inflating: data_gopala/arctic_a0247.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0247.wav
#   inflating: data_gopala/arctic_a0535.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0535.wav
#   inflating: data_gopala/arctic_a0509.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0509.wav
#   inflating: data_gopala/arctic_a0496.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0496.wav
#   inflating: data_gopala/arctic_a0482.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0482.wav
#   inflating: data_gopala/arctic_a0455.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0455.wav
#   inflating: data_gopala/arctic_a0333.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0333.wav
#   inflating: data_gopala/arctic_a0327.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0327.wav
#   inflating: data_gopala/arctic_a0441.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0441.wav
#   inflating: data_gopala/arctic_a0469.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0469.wav
#   inflating: data_gopala/arctic_a0131.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0131.wav
#   inflating: data_gopala/arctic_a0125.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0125.wav
#   inflating: data_gopala/arctic_a0119.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0119.wav
#   inflating: data_gopala/arctic_a0118.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0118.wav
#   inflating: data_gopala/arctic_a0124.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0124.wav
#   inflating: data_gopala/arctic_a0130.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0130.wav
#   inflating: data_gopala/arctic_a0468.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0468.wav
#   inflating: data_gopala/arctic_a0326.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0326.wav
#   inflating: data_gopala/arctic_a0440.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0440.wav
#   inflating: data_gopala/arctic_a0454.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0454.wav
#   inflating: data_gopala/arctic_a0332.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0332.wav
#   inflating: data_gopala/arctic_a0483.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0483.wav
#   inflating: data_gopala/arctic_a0497.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0497.wav
#   inflating: data_gopala/arctic_a0508.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0508.wav
#   inflating: data_gopala/arctic_a0252.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0252.wav
#   inflating: data_gopala/arctic_a0534.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0534.wav
#   inflating: data_gopala/arctic_a0520.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0520.wav
#   inflating: data_gopala/arctic_a0246.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0246.wav
#   inflating: data_gopala/arctic_a0291.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0291.wav
#   inflating: data_gopala/arctic_a0285.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0285.wav
#   inflating: data_gopala/arctic_a0078.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0078.wav
#   inflating: data_gopala/arctic_a0050.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0050.wav
#   inflating: data_gopala/arctic_a0044.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0044.wav
#   inflating: data_gopala/arctic_a0093.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0093.wav
#   inflating: data_gopala/arctic_a0087.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0087.wav
#   inflating: data_gopala/arctic_a0091.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0091.wav
#   inflating: data_gopala/arctic_a0085.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0085.wav
#   inflating: data_gopala/arctic_a0052.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0052.wav
#   inflating: data_gopala/arctic_a0046.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0046.wav
#   inflating: data_gopala/arctic_a0293.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0293.wav
#   inflating: data_gopala/arctic_a0287.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0287.wav
#   inflating: data_gopala/arctic_a0536.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0536.wav
#   inflating: data_gopala/arctic_a0250.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0250.wav
#   inflating: data_gopala/arctic_a0244.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0244.wav
#   inflating: data_gopala/test.csv
#   inflating: data_gopala/arctic_a0522.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0522.wav
#   inflating: data_gopala/arctic_a0278.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0278.wav
#   inflating: data_gopala/arctic_a0481.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0481.wav
#   inflating: data_gopala/arctic_a0495.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0495.wav
#   inflating: data_gopala/arctic_a0442.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0442.wav
#   inflating: data_gopala/arctic_a0324.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0324.wav
#   inflating: data_gopala/arctic_a0330.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0330.wav
#   inflating: data_gopala/arctic_a0456.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0456.wav
#   inflating: data_gopala/arctic_a0318.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0318.wav
#   inflating: data_gopala/arctic_a0126.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0126.wav
#   inflating: data_gopala/arctic_a0132.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0132.wav
#   inflating: data_gopala/arctic_a0133.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0133.wav
#   inflating: data_gopala/arctic_a0127.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0127.wav
#   inflating: data_gopala/arctic_a0319.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0319.wav
#   inflating: data_gopala/arctic_a0331.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0331.wav
#   inflating: data_gopala/arctic_a0457.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0457.wav
#   inflating: data_gopala/arctic_a0443.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0443.wav
#   inflating: data_gopala/arctic_a0325.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0325.wav
#   inflating: data_gopala/arctic_a0494.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0494.wav
#   inflating: data_gopala/arctic_a0480.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0480.wav
#   inflating: data_gopala/arctic_a0279.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0279.wav
#   inflating: data_gopala/arctic_a0245.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0245.wav
#   inflating: data_gopala/arctic_a0523.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0523.wav
#   inflating: data_gopala/arctic_a0537.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0537.wav
#   inflating: data_gopala/arctic_a0251.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0251.wav
#   inflating: data_gopala/arctic_a0286.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0286.wav
#   inflating: data_gopala/arctic_a0292.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0292.wav
#   inflating: data_gopala/arctic_a0047.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0047.wav
#   inflating: data_gopala/arctic_a0053.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0053.wav
#   inflating: data_gopala/arctic_a0084.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0084.wav
#   inflating: data_gopala/arctic_a0090.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0090.wav
#   inflating: data_gopala/arctic_a0094.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0094.wav
#   inflating: data_gopala/arctic_a0080.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0080.wav
#   inflating: data_gopala/arctic_a0057.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0057.wav
#   inflating: data_gopala/arctic_a0043.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0043.wav
#   inflating: data_gopala/arctic_a0296.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0296.wav
#   inflating: data_gopala/arctic_a0282.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0282.wav
#   inflating: data_gopala/arctic_a0269.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0269.wav
#   inflating: data_gopala/arctic_a0255.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0255.wav
#   inflating: data_gopala/arctic_a0533.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0533.wav
#   inflating: data_gopala/arctic_a0527.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0527.wav
#   inflating: data_gopala/arctic_a0241.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0241.wav
#   inflating: data_gopala/arctic_a0484.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0484.wav
#   inflating: data_gopala/arctic_a0490.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0490.wav
#   inflating: data_gopala/arctic_a0309.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0309.wav
#   inflating: data_gopala/arctic_a0321.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0321.wav
#   inflating: data_gopala/arctic_a0447.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0447.wav
#   inflating: data_gopala/arctic_a0453.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0453.wav
#   inflating: data_gopala/arctic_a0335.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0335.wav
#   inflating: data_gopala/arctic_a0123.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0123.wav
#   inflating: data_gopala/arctic_a0137.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0137.wav
#   inflating: data_gopala/arctic_a0136.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0136.wav
#   inflating: data_gopala/arctic_a0122.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0122.wav
#   inflating: data_gopala/arctic_a0452.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0452.wav
#   inflating: data_gopala/arctic_a0334.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0334.wav
#   inflating: data_gopala/arctic_a0320.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0320.wav
#   inflating: data_gopala/arctic_a0446.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0446.wav
#   inflating: data_gopala/arctic_a0308.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0308.wav
#   inflating: data_gopala/arctic_a0491.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0491.wav
#   inflating: data_gopala/arctic_a0485.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0485.wav
#   inflating: data_gopala/arctic_a0526.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0526.wav
#   inflating: data_gopala/arctic_a0240.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0240.wav
#   inflating: data_gopala/arctic_a0254.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0254.wav
#   inflating: data_gopala/arctic_a0532.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0532.wav
#   inflating: data_gopala/arctic_a0268.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0268.wav
#   inflating: data_gopala/arctic_a0283.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0283.wav
#   inflating: data_gopala/arctic_a0297.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0297.wav
#   inflating: data_gopala/arctic_a0042.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0042.wav
#   inflating: data_gopala/arctic_a0056.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0056.wav
#   inflating: data_gopala/arctic_a0081.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0081.wav
#   inflating: data_gopala/arctic_a0095.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0095.wav
#   inflating: data_gopala/arctic_a0083.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0083.wav
#   inflating: data_gopala/arctic_a0097.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0097.wav
#   inflating: data_gopala/arctic_a0068.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0068.wav
#   inflating: data_gopala/arctic_a0040.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0040.wav
#   inflating: data_gopala/arctic_a0054.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0054.wav
#   inflating: data_gopala/arctic_a0281.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0281.wav
#   inflating: data_gopala/arctic_a0295.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0295.wav
#   inflating: data_gopala/arctic_a0518.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0518.wav
#   inflating: data_gopala/arctic_a0242.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0242.wav
#   inflating: data_gopala/arctic_a0524.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0524.wav
#   inflating: data_gopala/arctic_a0530.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0530.wav
#   inflating: data_gopala/arctic_a0256.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0256.wav
#   inflating: data_gopala/arctic_a0493.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0493.wav
#   inflating: data_gopala/arctic_a0487.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0487.wav
#   inflating: data_gopala/arctic_a0478.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0478.wav
#   inflating: data_gopala/arctic_a0336.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0336.wav
#   inflating: data_gopala/arctic_a0450.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0450.wav
#   inflating: data_gopala/arctic_a0444.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0444.wav
#   inflating: data_gopala/arctic_a0322.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0322.wav
#   inflating: data_gopala/arctic_a0108.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0108.wav
#   inflating: data_gopala/arctic_a0134.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0134.wav
#   inflating: data_gopala/arctic_a0120.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0120.wav
#   inflating: data_gopala/arctic_a0121.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0121.wav
#   inflating: data_gopala/arctic_a0135.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0135.wav
#   inflating: data_gopala/arctic_a0109.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0109.wav
#   inflating: data_gopala/arctic_a0445.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0445.wav
#   inflating: data_gopala/arctic_a0323.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0323.wav
#   inflating: data_gopala/arctic_a0337.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0337.wav
#   inflating: data_gopala/arctic_a0451.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0451.wav
#   inflating: data_gopala/arctic_a0479.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0479.wav
#   inflating: data_gopala/arctic_a0486.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0486.wav
#   inflating: data_gopala/arctic_a0492.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0492.wav
#   inflating: data_gopala/arctic_a0531.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0531.wav
#   inflating: data_gopala/arctic_a0257.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0257.wav
#   inflating: data_gopala/arctic_a0243.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0243.wav
#   inflating: data_gopala/arctic_a0525.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0525.wav
#   inflating: data_gopala/arctic_a0519.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0519.wav
#   inflating: data_gopala/arctic_a0294.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0294.wav
#   inflating: data_gopala/arctic_a0280.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0280.wav
#   inflating: data_gopala/arctic_a0055.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0055.wav
#   inflating: data_gopala/arctic_a0041.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0041.wav
#   inflating: data_gopala/arctic_a0069.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0069.wav
#   inflating: data_gopala/arctic_a0096.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0096.wav
#   inflating: data_gopala/arctic_a0082.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0082.wav
#   inflating: data_gopala/arctic_a0064.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0064.wav
#   inflating: data_gopala/arctic_a0070.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0070.wav
#   inflating: data_gopala/arctic_a0058.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0058.wav
#   inflating: data_gopala/arctic_a0299.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0299.wav
#   inflating: data_gopala/arctic_a0500.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0500.wav
#   inflating: data_gopala/arctic_a0266.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0266.wav
#   inflating: data_gopala/arctic_a0272.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0272.wav
#   inflating: data_gopala/arctic_a0514.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0514.wav
#   inflating: data_gopala/arctic_a0528.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0528.wav
#   inflating: data_gopala/arctic_a0474.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0474.wav
#   inflating: data_gopala/arctic_a0312.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0312.wav
#   inflating: data_gopala/arctic_a0306.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0306.wav
#   inflating: data_gopala/arctic_a0460.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0460.wav
#   inflating: data_gopala/arctic_a0448.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0448.wav
#   inflating: data_gopala/arctic_a0110.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0110.wav
#   inflating: data_gopala/arctic_a0104.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0104.wav
#   inflating: data_gopala/arctic_a0138.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0138.wav
#   inflating: data_gopala/arctic_a0139.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0139.wav
#   inflating: data_gopala/arctic_a0105.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0105.wav
#   inflating: data_gopala/arctic_a0111.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0111.wav
#   inflating: data_gopala/arctic_a0449.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0449.wav
#   inflating: data_gopala/arctic_a0307.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0307.wav
#   inflating: data_gopala/arctic_a0461.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0461.wav
#   inflating: data_gopala/arctic_a0475.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0475.wav
#   inflating: data_gopala/arctic_a0313.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0313.wav
#   inflating: data_gopala/arctic_a0529.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0529.wav
#   inflating: data_gopala/arctic_a0273.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0273.wav
#   inflating: data_gopala/arctic_a0515.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0515.wav
#   inflating: data_gopala/arctic_a0501.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0501.wav
#   inflating: data_gopala/arctic_a0267.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0267.wav
#   inflating: data_gopala/arctic_a0298.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0298.wav
#   inflating: data_gopala/arctic_a0059.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0059.wav
#   inflating: data_gopala/arctic_a0071.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0071.wav
#   inflating: data_gopala/arctic_a0065.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0065.wav
#   inflating: data_gopala/arctic_a0098.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0098.wav
#   inflating: data_gopala/arctic_a0073.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0073.wav
#   inflating: data_gopala/arctic_a0067.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0067.wav
#   inflating: data_gopala/arctic_a0517.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0517.wav
#   inflating: data_gopala/arctic_a0271.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0271.wav
#   inflating: data_gopala/arctic_a0265.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0265.wav
#   inflating: data_gopala/arctic_a0503.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0503.wav
#   inflating: data_gopala/arctic_a0259.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0259.wav
#   inflating: data_gopala/arctic_a0488.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0488.wav
#   inflating: data_gopala/arctic_a0463.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0463.wav
#   inflating: data_gopala/arctic_a0305.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0305.wav
#   inflating: data_gopala/arctic_a0311.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0311.wav
#   inflating: data_gopala/arctic_a0477.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0477.wav
#   inflating: data_gopala/arctic_a0339.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0339.wav
#   inflating: data_gopala/arctic_a0107.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0107.wav
#   inflating: data_gopala/arctic_a0113.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0113.wav
#   inflating: data_gopala/arctic_a0112.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0112.wav
#   inflating: data_gopala/arctic_a0106.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0106.wav
#   inflating: data_gopala/arctic_a0338.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0338.wav
#   inflating: data_gopala/arctic_a0310.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0310.wav
#   inflating: data_gopala/arctic_a0476.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0476.wav
#   inflating: data_gopala/arctic_a0462.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0462.wav
#   inflating: data_gopala/arctic_a0304.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0304.wav
#   inflating: data_gopala/arctic_a0489.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0489.wav
#   inflating: data_gopala/arctic_a0258.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0258.wav
#   inflating: data_gopala/arctic_a0264.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0264.wav
#   inflating: data_gopala/arctic_a0502.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0502.wav
#   inflating: data_gopala/arctic_a0516.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0516.wav
#   inflating: data_gopala/arctic_a0270.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0270.wav
#   inflating: data_gopala/arctic_a0066.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0066.wav
#   inflating: data_gopala/arctic_a0072.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0072.wav
#   inflating: data_gopala/arctic_a0099.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0099.wav
#   inflating: data_gopala/arctic_a0089.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0089.wav
#   inflating: data_gopala/arctic_a0076.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0076.wav
#   inflating: data_gopala/arctic_a0062.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0062.wav
#   inflating: data_gopala/arctic_a0248.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0248.wav
#   inflating: data_gopala/arctic_a0274.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0274.wav
#   inflating: data_gopala/arctic_a0512.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0512.wav
#   inflating: data_gopala/arctic_a0506.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0506.wav
#   inflating: data_gopala/arctic_a0260.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0260.wav
#   inflating: data_gopala/arctic_a0499.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0499.wav
#   inflating: data_gopala/arctic_a0328.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0328.wav
#   inflating: data_gopala/arctic_a0300.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0300.wav
#   inflating: data_gopala/arctic_a0466.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0466.wav
#   inflating: data_gopala/arctic_a0472.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0472.wav
#   inflating: data_gopala/arctic_a0314.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0314.wav
#   inflating: data_gopala/arctic_a0102.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0102.wav
#   inflating: data_gopala/arctic_a0116.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0116.wav
#   inflating: data_gopala/arctic_a0117.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0117.wav
#   inflating: data_gopala/arctic_a0103.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0103.wav
#   inflating: data_gopala/arctic_a0473.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0473.wav
#   inflating: data_gopala/arctic_a0315.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0315.wav
#   inflating: data_gopala/arctic_a0301.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0301.wav
#   inflating: data_gopala/arctic_a0467.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0467.wav
#   inflating: data_gopala/arctic_a0329.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0329.wav
#   inflating: data_gopala/arctic_a0498.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0498.wav
#   inflating: data_gopala/arctic_a0507.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0507.wav
#   inflating: data_gopala/arctic_a0261.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0261.wav
#   inflating: data_gopala/arctic_a0275.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0275.wav
#   inflating: data_gopala/arctic_a0513.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0513.wav
#   inflating: data_gopala/arctic_a0249.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0249.wav
#   inflating: data_gopala/arctic_a0063.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0063.wav
#   inflating: data_gopala/arctic_a0077.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0077.wav
#   inflating: data_gopala/arctic_a0088.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0088.wav
#   inflating: data_gopala/arctic_a0049.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0049.wav
#   inflating: data_gopala/arctic_a0061.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0061.wav
#   inflating: data_gopala/arctic_a0075.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0075.wav
#   inflating: data_gopala/arctic_a0288.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0288.wav
#   inflating: data_gopala/arctic_a0539.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0539.wav
#   inflating: data_gopala/arctic_a0263.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0263.wav
#   inflating: data_gopala/arctic_a0505.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0505.wav
#   inflating: data_gopala/arctic_a0511.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0511.wav
#   inflating: data_gopala/arctic_a0277.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0277.wav
#   inflating: data_gopala/arctic_a0459.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0459.wav
#   inflating: data_gopala/arctic_a0317.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0317.wav
#   inflating: data_gopala/arctic_a0471.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0471.wav
#   inflating: data_gopala/arctic_a0465.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0465.wav
#   inflating: data_gopala/arctic_a0303.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0303.wav
#   inflating: data_gopala/arctic_a0129.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0129.wav
#   inflating: data_gopala/arctic_a0115.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0115.wav
#   inflating: data_gopala/arctic_a0101.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0101.wav
#   inflating: data_gopala/arctic_a0100.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0100.wav
#   inflating: data_gopala/arctic_a0114.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0114.wav
#   inflating: data_gopala/arctic_a0128.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0128.wav
#   inflating: data_gopala/arctic_a0464.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0464.wav
#   inflating: data_gopala/arctic_a0302.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0302.wav
#   inflating: data_gopala/arctic_a0316.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0316.wav
#   inflating: data_gopala/arctic_a0470.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0470.wav
#   inflating: data_gopala/arctic_a0458.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0458.wav
#   inflating: data_gopala/arctic_a0510.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0510.wav
#   inflating: data_gopala/arctic_a0276.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0276.wav
#   inflating: data_gopala/arctic_a0262.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0262.wav
#   inflating: data_gopala/arctic_a0504.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0504.wav
#   inflating: data_gopala/arctic_a0538.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0538.wav
#   inflating: data_gopala/arctic_a0289.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0289.wav
#   inflating: data_gopala/arctic_a0074.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0074.wav
#   inflating: data_gopala/arctic_a0060.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0060.wav
#   inflating: data_gopala/arctic_a0048.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0048.wav
#   inflating: data_gopala/arctic_a0007.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0007.wav
#   inflating: data_gopala/arctic_a0013.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0013.wav
#   inflating: data_gopala/train.csv
#   inflating: data_gopala/arctic_a0588.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0588.wav
#   inflating: data_gopala/arctic_a0205.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0205.wav
#   inflating: data_gopala/arctic_a0563.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0563.wav
#   inflating: data_gopala/arctic_a0577.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0577.wav
#   inflating: data_gopala/arctic_a0211.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0211.wav
#   inflating: data_gopala/arctic_a0239.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0239.wav
#   inflating: data_gopala/arctic_a0371.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0371.wav
#   inflating: data_gopala/arctic_a0417.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0417.wav
#   inflating: data_gopala/arctic_a0403.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0403.wav
#   inflating: data_gopala/arctic_a0365.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0365.wav
#   inflating: data_gopala/arctic_a0359.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0359.wav
#   inflating: data_gopala/arctic_a0198.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0198.wav
#   inflating: data_gopala/arctic_a0173.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0173.wav
#   inflating: data_gopala/arctic_a0167.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0167.wav
#   inflating: data_gopala/arctic_a0166.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0166.wav
#   inflating: data_gopala/arctic_a0172.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0172.wav
#   inflating: data_gopala/arctic_a0199.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0199.wav
#   inflating: data_gopala/arctic_a0358.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0358.wav
#   inflating: data_gopala/arctic_a0402.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0402.wav
#   inflating: data_gopala/arctic_a0364.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0364.wav
#   inflating: data_gopala/arctic_a0370.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0370.wav
#   inflating: data_gopala/arctic_a0416.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0416.wav
#   inflating: data_gopala/arctic_a0238.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0238.wav
#   inflating: data_gopala/arctic_a0576.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0576.wav
#   inflating: data_gopala/arctic_a0210.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0210.wav
#   inflating: data_gopala/arctic_a0204.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0204.wav
#   inflating: data_gopala/arctic_a0562.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0562.wav
#   inflating: data_gopala/arctic_a0589.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0589.wav
#   inflating: data_gopala/arctic_a0012.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0012.wav
#   inflating: data_gopala/arctic_a0006.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0006.wav
#   inflating: data_gopala/arctic_a0010.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0010.wav
#   inflating: data_gopala/arctic_a0004.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0004.wav
#   inflating: data_gopala/arctic_a0038.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0038.wav
#   inflating: data_gopala/arctic_a0212.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0212.wav
#   inflating: data_gopala/arctic_a0574.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0574.wav
#   inflating: data_gopala/arctic_a0560.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0560.wav
#   inflating: data_gopala/arctic_a0206.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0206.wav
#   inflating: data_gopala/arctic_a0548.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0548.wav
#   inflating: data_gopala/arctic_a0399.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0399.wav
#   inflating: data_gopala/arctic_a0366.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0366.wav
#   inflating: data_gopala/arctic_a0400.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0400.wav
#   inflating: data_gopala/arctic_a0414.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0414.wav
#   inflating: data_gopala/arctic_a0372.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0372.wav
#   inflating: data_gopala/arctic_a0428.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0428.wav
#   inflating: data_gopala/arctic_a0164.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0164.wav
#   inflating: data_gopala/arctic_a0170.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0170.wav
#   inflating: data_gopala/arctic_a0158.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0158.wav
#   inflating: data_gopala/arctic_a0159.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0159.wav
#   inflating: data_gopala/arctic_a0171.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0171.wav
#   inflating: data_gopala/arctic_a0165.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0165.wav
#   inflating: data_gopala/arctic_a0429.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0429.wav
#   inflating: data_gopala/arctic_a0415.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0415.wav
#   inflating: data_gopala/arctic_a0373.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0373.wav
#   inflating: data_gopala/arctic_a0367.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0367.wav
#   inflating: data_gopala/arctic_a0401.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0401.wav
#   inflating: data_gopala/arctic_a0398.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0398.wav
#   inflating: data_gopala/arctic_a0549.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0549.wav
#   inflating: data_gopala/arctic_a0561.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0561.wav
#   inflating: data_gopala/arctic_a0207.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0207.wav
#   inflating: data_gopala/arctic_a0213.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0213.wav
#   inflating: data_gopala/arctic_a0575.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0575.wav
#   inflating: data_gopala/arctic_a0039.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0039.wav
#   inflating: data_gopala/arctic_a0005.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0005.wav
#   inflating: data_gopala/arctic_a0011.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0011.wav
#   inflating: data_gopala/arctic_a0029.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0029.wav
#   inflating: data_gopala/arctic_a0015.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0015.wav
#   inflating: data_gopala/arctic_a0001.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0001.wav
#   inflating: data_gopala/arctic_a0559.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0559.wav
#   inflating: data_gopala/arctic_a0571.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0571.wav
#   inflating: data_gopala/arctic_a0217.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0217.wav
#   inflating: data_gopala/arctic_a0203.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0203.wav
#   inflating: data_gopala/arctic_a0565.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0565.wav
#   inflating: data_gopala/arctic_a0388.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0388.wav
#   inflating: data_gopala/arctic_a0439.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0439.wav
#   inflating: data_gopala/arctic_a0405.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0405.wav
#   inflating: data_gopala/arctic_a0363.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0363.wav
#   inflating: data_gopala/arctic_a0377.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0377.wav
#   inflating: data_gopala/arctic_a0411.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0411.wav
#   inflating: data_gopala/arctic_a0149.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0149.wav
#   inflating: data_gopala/arctic_a0161.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0161.wav
#   inflating: data_gopala/arctic_a0175.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0175.wav
#   inflating: data_gopala/arctic_a0174.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0174.wav
#   inflating: data_gopala/arctic_a0160.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0160.wav
#   inflating: data_gopala/arctic_a0148.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0148.wav
#   inflating: data_gopala/arctic_a0376.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0376.wav
#   inflating: data_gopala/arctic_a0410.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0410.wav
#   inflating: data_gopala/arctic_a0404.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0404.wav
#   inflating: data_gopala/arctic_a0362.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0362.wav
#   inflating: data_gopala/arctic_a0438.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0438.wav
#   inflating: data_gopala/arctic_a0389.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0389.wav
#   inflating: data_gopala/arctic_a0202.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0202.wav
#   inflating: data_gopala/arctic_a0564.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0564.wav
#   inflating: data_gopala/arctic_a0570.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0570.wav
#   inflating: data_gopala/arctic_a0216.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0216.wav
#   inflating: data_gopala/arctic_a0558.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0558.wav
#   inflating: data_gopala/arctic_a0014.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0014.wav
#   inflating: data_gopala/arctic_a0028.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0028.wav
#   inflating: data_gopala/arctic_a0002.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0002.wav
#   inflating: data_gopala/arctic_a0016.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0016.wav
#   inflating: data_gopala/arctic_a0228.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0228.wav
#   inflating: data_gopala/arctic_a0566.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0566.wav
#   inflating: data_gopala/arctic_a0200.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0200.wav
#   inflating: data_gopala/arctic_a0214.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0214.wav
#   inflating: data_gopala/arctic_a0572.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0572.wav
#   inflating: data_gopala/arctic_a0348.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0348.wav
#   inflating: data_gopala/arctic_a0412.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0412.wav
#   inflating: data_gopala/arctic_a0374.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0374.wav
#   inflating: data_gopala/arctic_a0360.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0360.wav
#   inflating: data_gopala/arctic_a0406.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0406.wav
#   inflating: data_gopala/arctic_a0189.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0189.wav
#   inflating: data_gopala/arctic_a0176.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0176.wav
#   inflating: data_gopala/arctic_a0162.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0162.wav
#   inflating: data_gopala/arctic_a0163.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0163.wav
#   inflating: data_gopala/arctic_a0177.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0177.wav
#   inflating: data_gopala/arctic_a0188.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0188.wav
#   inflating: data_gopala/arctic_a0361.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0361.wav
#   inflating: data_gopala/arctic_a0407.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0407.wav
#   inflating: data_gopala/arctic_a0413.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0413.wav
#   inflating: data_gopala/arctic_a0375.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0375.wav
#   inflating: data_gopala/arctic_a0349.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0349.wav
#   inflating: data_gopala/arctic_a0215.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0215.wav
#   inflating: data_gopala/arctic_a0573.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0573.wav
#   inflating: data_gopala/arctic_a0567.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0567.wav
#   inflating: data_gopala/arctic_a0201.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0201.wav
#   inflating: data_gopala/arctic_a0229.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0229.wav
#   inflating: data_gopala/arctic_a0017.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0017.wav
#   inflating: data_gopala/arctic_a0003.wav
#   inflating: __MACOSX/data_gopala/._arctic_a0003.wav

# %% [markdown]
# **Have a look at data_gopala folder!!** Your speech data is also suggested to follow the same format. Specifically, all you need is just a folder that contains wav files as well as csv files for train/dev/test respectively.

# %% [markdown]
# After replacing Gopala's voice with yours, no addtional efforts are needed afterwards. Just finish the fine-tuning experiments.

# %%
data = load_dataset("data_gopala")
# Out:
# WARNING:datasets.builder:Using custom data configuration data_gopala-becb09a439e1220e
# Downloading and preparing dataset csv/data_gopala to /root/.cache/huggingface/datasets/csv/data_gopala-becb09a439e1220e/0.0.0/6b9057d9e23d9d8a2f05b985917a0da84d70c5dae3d22ddd8a3f22fb01c69d9e...
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
# Dataset csv downloaded and prepared to /root/.cache/huggingface/datasets/csv/data_gopala-becb09a439e1220e/0.0.0/6b9057d9e23d9d8a2f05b985917a0da84d70c5dae3d22ddd8a3f22fb01c69d9e. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
data
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['file', 'text'],
#         num_rows: 472
#     })
#     test: Dataset({
#         features: ['file', 'text'],
#         num_rows: 58
#     })
#     validation: Dataset({
#         features: ['file', 'text'],
#         num_rows: 59
#     })
# })

# %% [markdown]
# Make sure your have train/dev/test split.

# %% [markdown]
# Let's write a short function to display some random samples of the dataset and run it a couple of times to get a feeling for the transcriptions.

# %%
from datasets import ClassLabel
import random
import pandas as pd
from IPython.display import display, HTML

def show_random_elements(dataset, num_examples=10):
    assert num_examples <= len(dataset), "Can't pick more elements than there are in the dataset."
    picks = []
    for _ in range(num_examples):
        pick = random.randint(0, len(dataset)-1)
        while pick in picks:
            pick = random.randint(0, len(dataset)-1)
        picks.append(pick)
    
    df = pd.DataFrame(dataset[picks])
    display(HTML(df.to_html()))

# %%
show_random_elements(data["train"].remove_columns(["file"]), num_examples=10)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>He did not rush in.</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Philip thrust himself against it and entered.</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Will we ever forget it.</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Since then some mysterious force has been fighting us at every step.</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>The night was calm and snowy.</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>I may manage to freight a cargo back as well.</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>My name's Ferguson.</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>It lasted as a deterrent for two days.</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>She turned, fearing that Jacques might see what was in her face.</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>He had been foiled in his attempt to escape.</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# We can see that the transcriptions contain some special characters, such as `,.?!;:`. Without a language model, it is much harder to classify speech chunks to such special characters because they don't really correspond to a characteristic sound unit. *E.g.*, the letter `"s"` has a more or less clear sound, whereas the special character `"."` does not.
# Also in order to understand the meaning of a speech signal, it is usually not necessary to include special characters in the transcription.
#
# In addition, we normalize the text to only have lower case letters and append a word separator token at the end.

# %%
import re
chars_to_ignore_regex = '[\,\?\.\!\-\;\:\"]'

def remove_special_characters(batch):
    batch["text"] = re.sub(chars_to_ignore_regex, '', batch["text"]).lower() + " "
    return batch

# %%
data = data.map(remove_special_characters)
# Out:
# WARNING:datasets.fingerprint:Parameter 'function'=<function remove_special_characters at 0x7f3e11bfd040> of the transform datasets.arrow_dataset.Dataset._map_single couldn't be hashed properly, a random hash was used instead. Make sure your transforms and parameters are serializable with pickle or dill for the dataset fingerprinting and caching to work. If you reuse this transform, the caching mechanism will consider it to be different from the previous calls and recompute everything. This warning is only showed once. Subsequent hashing failures won't be showed.
# 0ex [00:00, ?ex/s]
# 0ex [00:00, ?ex/s]
# 0ex [00:00, ?ex/s]

# %%
show_random_elements(data["train"].remove_columns(["file"]))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>with my strength i slammed it full into redeye's face</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>thus had the raw wilderness prepared him for this day</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>but life's worth more than cash she argued</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>she had died from cold and starvation</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>there is not an iota of truth in it certainly not</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>give them their choice between a fine or an official whipping</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>instead he joined her and they ate like two hungry children</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>eighteen hundred he calculated</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>it's the strap hangers that'll keep us from going under</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>you must sleep he urged</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Good! This looks better. We have removed most special characters from transcriptions and normalized them to lower-case only.
#
# In CTC, it is common to classify speech chunks into letters, so we will do the same here.
# Let's extract all distinct letters of the training and test data and build our vocabulary from this set of letters.
#
# We write a mapping function that concatenates all transcriptions into one long transcription and then transforms the string into a set of chars.
# It is important to pass the argument `batched=True` to the `map(...)` function so that the mapping function has access to all transcriptions at once.

# %%
def extract_all_chars(batch):
  all_text = " ".join(batch["text"])
  vocab = list(set(all_text))
  return {"vocab": [vocab], "all_text": [all_text]}

# %%
vocabs = data.map(extract_all_chars, batched=True, batch_size=-1, keep_in_memory=True, remove_columns=data.column_names["train"])
# Out:
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]

# %% [markdown]
# Now, we create the union of all distinct letters in the training dataset and test dataset and convert the resulting list into an enumerated dictionary.

# %%
vocab_list = list(set(vocabs["train"]["vocab"][0]))

# %%
vocab_dict = {v: k for k, v in enumerate(vocab_list)}
vocab_dict
# Out:
# {'x': 0,
#  'u': 1,
#  'c': 2,
#  'd': 3,
#  'o': 4,
#  'b': 5,
#  'i': 6,
#  'q': 7,
#  'm': 8,
#  'w': 9,
#  's': 10,
#  'a': 11,
#  'e': 12,
#  'y': 13,
#  'h': 14,
#  'z': 15,
#  'l': 16,
#  'k': 17,
#  "'": 18,
#  't': 19,
#  'n': 20,
#  'p': 21,
#  ' ': 22,
#  'f': 23,
#  'v': 24,
#  'j': 25,
#  'g': 26,
#  'r': 27}

# %% [markdown]
# Cool, we see that all letters of the alphabet occur in the dataset (which is not really surprising) and we also extracted the special characters `" "` and `'`. Note that we did not exclude those special characters because:
#
# - The model has to learn to predict when a word finished or else the model prediction would always be a sequence of chars which would make it impossible to separate words from each other.
# - In English, we need to keep the `'` character to differentiate between words, *e.g.*, `"it's"` and `"its"` which have very different meanings.

# %% [markdown]
# To make it clearer that `" "` has its own token class, we give it a more visible character `|`. In addition, we also add an "unknown" token so that the model can later deal with characters not encountered in training set.
#
# Finally, we also add a padding token that corresponds to CTC's "*blank token*". The "blank token" is a core component of the CTC algorithm. For more information, please take a look at the "Alignment" section [here](https://distill.pub/2017/ctc/).

# %%
vocab_dict["|"] = vocab_dict[" "]
del vocab_dict[" "]

# %%
vocab_dict["[UNK]"] = len(vocab_dict)
vocab_dict["[PAD]"] = len(vocab_dict)
len(vocab_dict)
# Out:
# 30

# %% [markdown]
# Cool, now our vocabulary is complete and consists of 30 tokens, which means that the linear layer that we will add on top of the pretrained Wav2Vec2 checkpoint will have an output dimension of 30.

# %% [markdown]
# Let's now save the vocabulary as a json file.

# %%
import json
with open('vocab.json', 'w') as vocab_file:
    json.dump(vocab_dict, vocab_file)

# %% [markdown]
# In a final step, we use the json file to instantiate an object of the `Wav2Vec2CTCTokenizer` class.

# %% [markdown]
# ### Create Wav2Vec2CTCTokenizer

# %% [markdown]
# The [pretrained Wav2Vec2 checkpoint]( ) maps the speech signal to a sequence of context representations as illustrated in the figure above. A fine-tuned Wav2Vec2 checkpoint needs to map this sequence of context representations to its corresponding transcription so that a linear layer has to be added on top of the transformer block (shown in yellow). This linear layer is used to classifies each context representation to a token class analogous how, *e.g.*, after pretraining a linear layer is added on top of BERT's embeddings for further classification - *cf.* with *"BERT"* section of this [blog post](https://huggingface.co/blog/warm-starting-encoder-decoder).
#
# The output size of this layer corresponds to the number of tokens in the vocabulary, which does **not** depend on Wav2Vec2's pretraining task, but only on the labeled dataset used for fine-tuning.

# %%
from transformers import Wav2Vec2CTCTokenizer

tokenizer = Wav2Vec2CTCTokenizer("./vocab.json", unk_token="[UNK]", pad_token="[PAD]", word_delimiter_token="|")

# %% [markdown]
# # Training_args
#
# This training_args does not mean we are going to train the model. We have to move this part here to avoid crash issues. If you are going tune the hyper-parameters to get better WER, just modify the arguments here.

# %%
repo_name = 'wav2vec2-gopala'
from transformers import TrainingArguments

training_args = TrainingArguments(
  output_dir=repo_name,
  group_by_length=True,
  per_device_train_batch_size=2,
  evaluation_strategy="steps",
  num_train_epochs=30,
  fp16=True,
  gradient_checkpointing=True,
  save_steps=500,
  eval_steps=500,
  logging_steps=500,
  learning_rate=1e-4,
  weight_decay=0.005,
  warmup_steps=1000,
  save_total_limit=2,
)

# %% [markdown]
# ### Create Wav2Vec2 Feature Extractor

# %% [markdown]
# A Wav2Vec2 feature extractor object requires the following parameters to be instantiated:
#
# - `feature_size`: Speech models take a sequence of feature vectors as an input. While the length of this sequence obviously varies, the feature size should not. In the case of Wav2Vec2, the feature size is 1 because the model was trained on the raw speech signal ${}^2$.
# - `sampling_rate`: The sampling rate at which the model is trained on.
# - `padding_value`: For batched inference, shorter inputs need to be padded with a specific value
# - `do_normalize`: Whether the input should be *zero-mean-unit-variance* normalized or not. Usually, speech models perform better when normalizing the input
# - `return_attention_mask`: Whether the model should make use of an `attention_mask` for batched inference. In general, models should **always** make use of the `attention_mask` to mask padded tokens. However, due to a very specific design choice of `Wav2Vec2`'s "base" checkpoint, better results are achieved when using no `attention_mask`. This is **not** recommended for other speech models. For more information, one can take a look at [this](https://github.com/pytorch/fairseq/issues/3227) issue. **Important** If you want to use this notebook to fine-tune [large-lv60](https://huggingface.co/facebook/wav2vec2-large-lv60), this parameter should be set to `True`.

# %%
from transformers import Wav2Vec2FeatureExtractor

feature_extractor = Wav2Vec2FeatureExtractor(feature_size=1, sampling_rate=16000, padding_value=0.0, do_normalize=True, return_attention_mask=False)

# %% [markdown]
# Great, Wav2Vec2's feature extraction pipeline is thereby fully defined!
#
# To make the usage of Wav2Vec2 as user-friendly as possible, the feature extractor and tokenizer are *wrapped* into a single `Wav2Vec2Processor` class so that one only needs a `model` and `processor` object.

# %%
from transformers import Wav2Vec2Processor

processor = Wav2Vec2Processor(feature_extractor=feature_extractor, tokenizer=tokenizer)

# %% [markdown]
# Next, we can prepare the dataset.

# %%
data["train"][0]["file"]
# Out:
# 'data_gopala/arctic_a0001.wav'

# %% [markdown]
# Great, let's listen to a couple of audio files to better understand the dataset and verify that the audio was correctly loaded.
#
# **Note**: *You can click the following cell a couple of times to listen to different speech samples.*

# %%
import IPython.display as ipd
import numpy as np
import random
import torchaudio

rand_int = random.randint(0, len(data["train"]))

print(data["train"][rand_int]["text"])
wav, _ = torchaudio.load(data['train'][rand_int]['file'])
ipd.Audio(data=np.asarray(wav), autoplay=True, rate=16000)
# Out:
# it was not exactly a deportation
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# It can be heard, that the speakers change along with their speaking rate, accent, etc. Overall, the recordings sound relatively clear though, which is to be expected from a read speech corpus.
#
# Let's do a final check that the data is correctly prepared, by printing the shape of the speech input, its transcription, and the corresponding sampling rate.
#
# **Note**: *You can click the following cell a couple of times to verify multiple samples.*

# %% [markdown]
# Finally, we can process the dataset to the format expected by the model for training. We will make use of the `map(...)` function.
#
# First, we load and resample the audio data, simply by calling `batch["audio"]`.
# Second, we extract the `input_values` from the loaded audio file. In our case, the `Wav2Vec2Processor` only normalizes the data. For other speech models, however, this step can include more complex feature extraction, such as [Log-Mel feature extraction](https://en.wikipedia.org/wiki/Mel-frequency_cepstrum).
# Third, we encode the transcriptions to label ids.
#
# **Note**: This mapping function is a good example of how the `Wav2Vec2Processor` class should be used. In "normal" context, calling `processor(...)` is redirected to `Wav2Vec2FeatureExtractor`'s call method. When wrapping the processor into the `as_target_processor` context, however, the same method is redirected to `Wav2Vec2CTCTokenizer`'s call method.
# For more information please check the [docs](https://huggingface.co/transformers/master/model_doc/wav2vec2.html#transformers.Wav2Vec2Processor.__call__).

# %%
def prepare_dataset(batch):

    audio, _ = torchaudio.load(batch['file'])
    audio = audio.numpy().reshape(-1)
    batch["input_values"] = audio
    batch["input_length"] = len(batch["input_values"])

    with processor.as_target_processor():
        batch["labels"] = processor(batch["text"]).input_ids
    return batch

# %% [markdown]
# Let's apply the data preparation function to all examples.

# %%
data = data.map(prepare_dataset, remove_columns=data.column_names["train"], num_proc=4)

# %% [markdown]
# **Note**: Currently `datasets` make use of [`torchaudio`](https://pytorch.org/audio/stable/index.html) and [`librosa`](https://librosa.org/doc/latest/index.html) for audio loading and resampling. If you wish to implement your own costumized data loading/sampling, feel free to just make use of the `"path"` column instead and disregard the `"audio"` column.

# %% [markdown]
# Long input sequences require a lot of memory. Since `Wav2Vec2` is based on `self-attention` the memory requirement scales quadratically with the input length for long input sequences (*cf.* with [this](https://www.reddit.com/r/MachineLearning/comments/genjvb/d_why_is_the_maximum_input_sequence_length_of/) reddit post). For this demo, let's filter all sequences that are longer than 4 seconds out of the training dataset.

# %%
max_input_length_in_sec = 4.0
data["train"] = data["train"].filter(lambda x: x < max_input_length_in_sec * processor.feature_extractor.sampling_rate, input_columns=["input_length"])
# Out:
#   0%|          | 0/1 [00:00<?, ?ba/s]

# %% [markdown]
# Awesome, now we are ready to start training!

# %% [markdown]
# ### Set-up Dataloader
#
# Let's start by defining the data collator. The code for the data collator was copied from [this example](https://github.com/huggingface/transformers/blob/9a06b6b11bdfc42eea08fa91d0c737d1863c99e3/examples/research_projects/wav2vec2/run_asr.py#L81).

# %%
import torch

from dataclasses import dataclass, field
from typing import Any, Dict, List, Optional, Union

@dataclass
class DataCollatorCTCWithPadding:
    """
    Data collator that will dynamically pad the inputs received.
    Args:
        processor (:class:`~transformers.Wav2Vec2Processor`)
            The processor used for proccessing the data.
        padding (:obj:`bool`, :obj:`str` or :class:`~transformers.tokenization_utils_base.PaddingStrategy`, `optional`, defaults to :obj:`True`):
            Select a strategy to pad the returned sequences (according to the model's padding side and padding index)
            among:
            * :obj:`True` or :obj:`'longest'`: Pad to the longest sequence in the batch (or no padding if only a single
              sequence if provided).
            * :obj:`'max_length'`: Pad to a maximum length specified with the argument :obj:`max_length` or to the
              maximum acceptable input length for the model if that argument is not provided.
            * :obj:`False` or :obj:`'do_not_pad'` (default): No padding (i.e., can output a batch with sequences of
              different lengths).
    """

    processor: Wav2Vec2Processor
    padding: Union[bool, str] = True

    def __call__(self, features: List[Dict[str, Union[List[int], torch.Tensor]]]) -> Dict[str, torch.Tensor]:
        # split inputs and labels since they have to be of different lenghts and need
        # different padding methods
        input_features = [{"input_values": feature["input_values"]} for feature in features]
        label_features = [{"input_ids": feature["labels"]} for feature in features]

        batch = self.processor.pad(
            input_features,
            padding=self.padding,
            return_tensors="pt",
        )
        with self.processor.as_target_processor():
            labels_batch = self.processor.pad(
                label_features,
                padding=self.padding,
                return_tensors="pt",
            )

        # replace padding with -100 to ignore loss correctly
        labels = labels_batch["input_ids"].masked_fill(labels_batch.attention_mask.ne(1), -100)

        batch["labels"] = labels

        return batch

# %%
data_collator = DataCollatorCTCWithPadding(processor=processor, padding=True)

# %% [markdown]
# Next, the evaluation metric is defined. As mentioned earlier, the
# predominant metric in ASR is the word error rate (WER), hence we will use it in this notebook as well.

# %%
wer_metric = load_metric("wer")
# Out:
# Downloading:   0%|          | 0.00/1.90k [00:00<?, ?B/s]

# %% [markdown]
# The model will return a sequence of logit vectors:
# $\mathbf{y}_1, \ldots, \mathbf{y}_m$ with $\mathbf{y}_1 = f_{\theta}(x_1, \ldots, x_n)[0]$ and $n >> m$.
#
# A logit vector $\mathbf{y}_1$ contains the log-odds for each word in the vocabulary we defined earlier, thus $\text{len}(\mathbf{y}_i) =$ `config.vocab_size`. We are interested in the most likely prediction of the model and thus take the `argmax(...)` of the logits. Also, we transform the encoded labels back to the original string by replacing `-100` with the `pad_token_id` and decoding the ids while making sure that consecutive tokens are **not** grouped to the same token in CTC style ${}^1$.

# %%
def compute_metrics(pred):
    pred_logits = pred.predictions
    pred_ids = np.argmax(pred_logits, axis=-1)

    pred.label_ids[pred.label_ids == -100] = processor.tokenizer.pad_token_id

    pred_str = processor.batch_decode(pred_ids)
    # we do not want to group tokens when computing the metrics
    label_str = processor.batch_decode(pred.label_ids, group_tokens=False)

    wer = wer_metric.compute(predictions=pred_str, references=label_str)

    return {"wer": wer}

# %% [markdown]
# Now, we can load the pretrained `Wav2Vec2` checkpoint. The tokenizer's `pad_token_id` must be to define the model's `pad_token_id` or in the case of `Wav2Vec2ForCTC` also CTC's *blank token* ${}^2$. To save GPU memory, we enable PyTorch's [gradient checkpointing](https://pytorch.org/docs/stable/checkpoint.html) and also set the loss reduction to "*mean*".

# %%
from transformers import Wav2Vec2ForCTC

model = Wav2Vec2ForCTC.from_pretrained(
    "facebook/wav2vec2-base",
    ctc_loss_reduction="mean", 
    pad_token_id=processor.tokenizer.pad_token_id,
)
# Out:
# Downloading:   0%|          | 0.00/1.80k [00:00<?, ?B/s]
# /usr/local/lib/python3.8/dist-packages/transformers/configuration_utils.py:356: UserWarning: Passing `gradient_checkpointing` to a config initialization is deprecated and will be removed in v5 Transformers. Using `model.gradient_checkpointing_enable()` instead, or if you are using the `Trainer` API, pass `gradient_checkpointing=True` in your `TrainingArguments`.
#   warnings.warn(
# Downloading:   0%|          | 0.00/363M [00:00<?, ?B/s]
# Some weights of the model checkpoint at facebook/wav2vec2-base were not used when initializing Wav2Vec2ForCTC: ['quantizer.weight_proj.weight', 'quantizer.codevectors', 'project_q.weight', 'project_hid.weight', 'project_hid.bias', 'quantizer.weight_proj.bias', 'project_q.bias']
# - This IS expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at facebook/wav2vec2-base and are newly initialized: ['lm_head.weight', 'lm_head.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
model = model.cuda()

# %% [markdown]
# ### Training
#
# Typically, it is useful to freeze the encoder for low resource/few show settings.

# %%
model.freeze_feature_encoder()

# %% [markdown]
# Now, all instances can be passed to Trainer and we are ready to start training!

# %%
from transformers import Trainer


trainer = Trainer(
    model=model,
    data_collator=data_collator,
    args=training_args,
    compute_metrics=compute_metrics,
    train_dataset=data["train"],
    eval_dataset=data["validation"],
    tokenizer=processor.feature_extractor,
)
# Out:
# Using amp half precision backend

# %% [markdown]
# ---
#
# ${}^1$ To allow models to become independent of the speaker rate, in CTC, consecutive tokens that are identical are simply grouped as a single token. However, the encoded labels should not be grouped when decoding since they don't correspond to the predicted tokens of the model, which is why the `group_tokens=False` parameter has to be passed. If we wouldn't pass this parameter a word like `"hello"` would incorrectly be encoded, and decoded as `"helo"`.
#
# ${}^2$ The blank token allows the model to predict a word, such as `"hello"` by forcing it to insert the blank token between the two l's. A CTC-conform prediction of `"hello"` of our model would be `[PAD] [PAD] "h" "e" "e" "l" "l" [PAD] "l" "o" "o" [PAD]`.

# %% [markdown]
# ```javascript
# function ConnectButton(){
#     console.log("Connect pushed");
#     document.querySelector("#top-toolbar > colab-connect-button").shadowRoot.querySelector("#connect").click()
# }
# setInterval(ConnectButton,60000);
# ```

# %% [markdown]
# Depending on what GPU was allocated to your google colab it might be possible that you are seeing an `"out-of-memory"` error here. In this case, it's probably best to reduce `per_device_train_batch_size` to 16 or even less and eventually make use of [`gradient_accumulation`](https://huggingface.co/transformers/master/main_classes/trainer.html#trainingarguments).

# %%
trainer.train()
# Out:
# The following columns in the training set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# /usr/local/lib/python3.8/dist-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 357
#   Num Epochs = 30
#   Instantaneous batch size per device = 2
#   Total train batch size (w. parallel, distributed & accumulation) = 2
#   Gradient Accumulation steps = 1
#   Total optimization steps = 5370
#     <div>
#
#       <progress value='5370' max='5370' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5370/5370 12:51, Epoch 30/30]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Wer</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>3.794900</td>
#       <td>2.926010</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>1.341600</td>
#       <td>0.925877</td>
#       <td>0.634429</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.540700</td>
#       <td>0.758065</td>
#       <td>0.572534</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.325000</td>
#       <td>0.768594</td>
#       <td>0.477756</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.236100</td>
#       <td>0.917356</td>
#       <td>0.495164</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.158600</td>
#       <td>0.903034</td>
#       <td>0.456480</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.121500</td>
#       <td>0.919155</td>
#       <td>0.458414</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.087600</td>
#       <td>1.016765</td>
#       <td>0.458414</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.065300</td>
#       <td>0.951501</td>
#       <td>0.441006</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.050200</td>
#       <td>0.957699</td>
#       <td>0.454545</td>
#     </tr>
#   </tbody>
# </table><p>
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 59
#   Batch size = 8
# Saving model checkpoint to wav2vec2-gopala/checkpoint-500
# Configuration saved in wav2vec2-gopala/checkpoint-500/config.json
# Model weights saved in wav2vec2-gopala/checkpoint-500/pytorch_model.bin
# Feature extractor saved in wav2vec2-gopala/checkpoint-500/preprocessor_config.json
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 59
#   Batch size = 8
# Saving model checkpoint to wav2vec2-gopala/checkpoint-1000
# Configuration saved in wav2vec2-gopala/checkpoint-1000/config.json
# Model weights saved in wav2vec2-gopala/checkpoint-1000/pytorch_model.bin
# Feature extractor saved in wav2vec2-gopala/checkpoint-1000/preprocessor_config.json
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 59
#   Batch size = 8
# Saving model checkpoint to wav2vec2-gopala/checkpoint-1500
# Configuration saved in wav2vec2-gopala/checkpoint-1500/config.json
# Model weights saved in wav2vec2-gopala/checkpoint-1500/pytorch_model.bin
# Feature extractor saved in wav2vec2-gopala/checkpoint-1500/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-gopala/checkpoint-500] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 59
#   Batch size = 8
# Saving model checkpoint to wav2vec2-gopala/checkpoint-2000
# Configuration saved in wav2vec2-gopala/checkpoint-2000/config.json
# Model weights saved in wav2vec2-gopala/checkpoint-2000/pytorch_model.bin
# Feature extractor saved in wav2vec2-gopala/checkpoint-2000/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-gopala/checkpoint-1000] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 59
#   Batch size = 8
# Saving model checkpoint to wav2vec2-gopala/checkpoint-2500
# Configuration saved in wav2vec2-gopala/checkpoint-2500/config.json
# Model weights saved in wav2vec2-gopala/checkpoint-2500/pytorch_model.bin
# Feature extractor saved in wav2vec2-gopala/checkpoint-2500/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-gopala/checkpoint-1500] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 59
#   Batch size = 8
# Saving model checkpoint to wav2vec2-gopala/checkpoint-3000
# Configuration saved in wav2vec2-gopala/checkpoint-3000/config.json
# Model weights saved in wav2vec2-gopala/checkpoint-3000/pytorch_model.bin
# Feature extractor saved in wav2vec2-gopala/checkpoint-3000/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-gopala/checkpoint-2000] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 59
#   Batch size = 8
# Saving model checkpoint to wav2vec2-gopala/checkpoint-3500
# Configuration saved in wav2vec2-gopala/checkpoint-3500/config.json
# Model weights saved in wav2vec2-gopala/checkpoint-3500/pytorch_model.bin
# Feature extractor saved in wav2vec2-gopala/checkpoint-3500/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-gopala/checkpoint-2500] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 59
#   Batch size = 8
# Saving model checkpoint to wav2vec2-gopala/checkpoint-4000
# Configuration saved in wav2vec2-gopala/checkpoint-4000/config.json
# Model weights saved in wav2vec2-gopala/checkpoint-4000/pytorch_model.bin
# Feature extractor saved in wav2vec2-gopala/checkpoint-4000/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-gopala/checkpoint-3000] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 59
#   Batch size = 8
# Saving model checkpoint to wav2vec2-gopala/checkpoint-4500
# Configuration saved in wav2vec2-gopala/checkpoint-4500/config.json
# Model weights saved in wav2vec2-gopala/checkpoint-4500/pytorch_model.bin
# Feature extractor saved in wav2vec2-gopala/checkpoint-4500/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-gopala/checkpoint-3500] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 59
#   Batch size = 8
# Saving model checkpoint to wav2vec2-gopala/checkpoint-5000
# Configuration saved in wav2vec2-gopala/checkpoint-5000/config.json
# Model weights saved in wav2vec2-gopala/checkpoint-5000/pytorch_model.bin
# Feature extractor saved in wav2vec2-gopala/checkpoint-5000/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-gopala/checkpoint-4000] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=5370, training_loss=0.6290618896484375, metrics={'train_runtime': 780.8564, 'train_samples_per_second': 13.716, 'train_steps_per_second': 6.877, 'total_flos': 2.8478360439667296e+17, 'train_loss': 0.6290618896484375, 'epoch': 30.0})

# %% [markdown]
# The final dev WER here is about 0.41.

# %% [markdown]
# ### Evaluate
#
# In the final part, we run our model on some of the validation data to get a feeling for how well it works.
#
# Let's load the `model`. Make sure the model path exists.!

# %%
model = Wav2Vec2ForCTC.from_pretrained("wav2vec2-gopala/checkpoint-5000").cuda()
# Out:
# loading configuration file wav2vec2-gopala/checkpoint-5000/config.json
# Model config Wav2Vec2Config {
#   "_name_or_path": "facebook/wav2vec2-base",
#   "activation_dropout": 0.0,
#   "adapter_kernel_size": 3,
#   "adapter_stride": 2,
#   "add_adapter": false,
#   "apply_spec_augment": true,
#   "architectures": [
#     "Wav2Vec2ForCTC"
#   ],
#   "attention_dropout": 0.1,
#   "bos_token_id": 1,
#   "classifier_proj_size": 256,
#   "codevector_dim": 256,
#   "contrastive_logits_temperature": 0.1,
#   "conv_bias": false,
#   "conv_dim": [
#     512,
#     512,
#     512,
#     512,
#     512,
#     512,
#     512
#   ],
#   "conv_kernel": [
#     10,
#     3,
#     3,
#     3,
#     3,
#     2,
#     2
#   ],
#   "conv_stride": [
#     5,
#     2,
#     2,
#     2,
#     2,
#     2,
#     2
#   ],
#   "ctc_loss_reduction": "mean",
#   "ctc_zero_infinity": false,
#   "diversity_loss_weight": 0.1,
#   "do_stable_layer_norm": false,
#   "eos_token_id": 2,
#   "feat_extract_activation": "gelu",
#   "feat_extract_norm": "group",
#   "feat_proj_dropout": 0.1,
#   "feat_quantizer_dropout": 0.0,
#   "final_dropout": 0.0,
#   "freeze_feat_extract_train": true,
#   "hidden_act": "gelu",
#   "hidden_dropout": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-05,
#   "layerdrop": 0.0,
#   "mask_channel_length": 10,
#   "mask_channel_min_space": 1,
#   "mask_channel_other": 0.0,
#   "mask_channel_prob": 0.0,
#   "mask_channel_selection": "static",
#   "mask_feature_length": 10,
#   "mask_feature_min_masks": 0,
#   "mask_feature_prob": 0.0,
#   "mask_time_length": 10,
#   "mask_time_min_masks": 2,
#   "mask_time_min_space": 1,
#   "mask_time_other": 0.0,
#   "mask_time_prob": 0.05,
#   "mask_time_selection": "static",
#   "model_type": "wav2vec2",
#   "no_mask_channel_overlap": false,
#   "no_mask_time_overlap": false,
#   "num_adapter_layers": 3,
#   "num_attention_heads": 12,
#   "num_codevector_groups": 2,
#   "num_codevectors_per_group": 320,
#   "num_conv_pos_embedding_groups": 16,
#   "num_conv_pos_embeddings": 128,
#   "num_feat_extract_layers": 7,
#   "num_hidden_layers": 12,
#   "num_negatives": 100,
#   "output_hidden_size": 768,
#   "pad_token_id": 29,
#   "proj_codevector_dim": 256,
#   "tdnn_dilation": [
#     1,
#     2,
#     3,
#     1,
#     1
#   ],
#   "tdnn_dim": [
#     512,
#     512,
#     512,
#     512,
#     1500
#   ],
#   "tdnn_kernel": [
#     5,
#     3,
#     3,
#     1,
#     1
#   ],
#   "torch_dtype": "float32",
#   "transformers_version": "4.17.0",
#   "use_weighted_layer_sum": false,
#   "vocab_size": 32,
#   "xvector_output_dim": 512
# }
#
# loading weights file wav2vec2-gopala/checkpoint-5000/pytorch_model.bin
# All model checkpoint weights were used when initializing Wav2Vec2ForCTC.
#
# All the weights of Wav2Vec2ForCTC were initialized from the model checkpoint at wav2vec2-gopala/checkpoint-5000.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use Wav2Vec2ForCTC for predictions without further training.

# %% [markdown]
# Now, we will make use of the `map(...)` function to predict the transcription of every test sample and to save the prediction in the dataset itself. We will call the resulting dictionary `"results"`.
#
# **Note**: we evaluate the test data set with `batch_size=1` on purpose due to this [issue](https://github.com/pytorch/fairseq/issues/3227). Since padded inputs don't yield the exact same output as non-padded inputs, a better WER can be achieved by not padding the input at all.

# %%
def map_to_result(batch):
  with torch.no_grad():
    input_values = torch.tensor(batch["input_values"]).unsqueeze(0)
    input_values = input_values.cuda()
    logits = model(input_values).logits

  pred_ids = torch.argmax(logits, dim=-1)
  batch["pred_str"] = processor.batch_decode(pred_ids)[0]
  batch["text"] = processor.decode(batch["labels"], group_tokens=False)
  
  return batch

# %%
results = data["test"].map(map_to_result, remove_columns=data["test"].column_names)
# Out:
# 0ex [00:00, ?ex/s]

# %% [markdown]
# Let's compute the overall test WER!

# %%
print("Test WER: {:.3f}".format(wer_metric.compute(predictions=results["pred_str"], references=results["text"])))
# Out:
# Test WER: 0.282

# %% [markdown]
# Let's take a look at some predictions to see what errors are made by the model.

# %%
show_random_elements(results)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>pred_str</th>
#       <th>text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>he was an enthusiast and a deseirt weller</td>
#       <td>he was an enthusiast and a desert dweller</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>aenjoyit he did but principally for s twoords sake</td>
#       <td>enjoy it he did but principally for steward's sake</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>i am righting these lines in honoluldu hawai</td>
#       <td>i am writing these lines in honolulu hawaii</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>all an appearance can know is murage</td>
#       <td>all an appearance can know is mirage</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>this also became part of the dayly skedual</td>
#       <td>this also became part of the daily schedule</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>he may antisipatethe daye of his death</td>
#       <td>he may anticipate the day of his death</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>without a dout som of them have dinner angagements</td>
#       <td>without a doubt some of them have dinner engagements</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>there was the emma lueesa</td>
#       <td>there was the emma louisa</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>sheld make a good wife for the cassiear</td>
#       <td>she'd make a good wife for the cashier</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>behind him lay the thousend years long grod acrass all sibearia and rasha</td>
#       <td>behind him lay the thousandyearslong road across all siberia and russia</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# It becomes clear that the predicted transcriptions are acoustically very similar to the target transcriptions, but often contain spelling or grammatical errors. This shouldn't be very surprising though given that we purely rely on Wav2Vec2 without making use of a language model.

# %% [markdown]
# Finally, to better understand how CTC works, it is worth taking a deeper look at the exact output of the model. Let's run the first test sample through the model, take the predicted ids and convert them to their corresponding tokens.

# %%
model.to("cuda")

with torch.no_grad():
  logits = model(torch.tensor(data["test"][:1]["input_values"], device="cuda")).logits

pred_ids = torch.argmax(logits, dim=-1)

# convert ids to tokens
" ".join(processor.tokenizer.convert_ids_to_tokens(pred_ids[0].tolist()))
# Out:
# '[PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] h h e | | w o u l l d | | d [PAD] e e [PAD] s s s [PAD] [PAD] [PAD] t t r r r o o o o o y y y y | | [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] a a l l [PAD] [PAD] [PAD] l l l | | [PAD] [PAD] [PAD] t t h h i n n n g g g [PAD] [PAD] [PAD] [PAD] [PAD] s s | | | [PAD] [PAD] t t h h a t t | | a a r r e e | | f f [PAD] [PAD] [PAD] i c x [PAD] [PAD] [PAD] [PAD] e | | | [PAD]'

# %% [markdown]
# The output should make it a bit clearer how CTC works in practice. The model is to some extent invariant to speaking rate since it has learned to either just repeat the same token in case the speech chunk to be classified still corresponds to the same token. This makes CTC a very powerful algorithm for speech recognition since the speech file's transcription is often very much independent of its length.
